# %% [markdown]
# # TP-MCTS on Colab
#
# This notebook clones the repo and runs a single experiment.

# %%
# Clone repo
# !git clone https://github.com/taliBerman5/TP_MCTS.git
# %cd TP_MCTS
# Out:
# Cloning into 'TP_MCTS'...
# remote: Enumerating objects: 2135, done.
# remote: Counting objects: 100% (280/280), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 2135 (delta 170), reused 245 (delta 147), pack-reused 1855 (from 1)
# Receiving objects: 100% (2135/2135), 13.92 MiB | 5.89 MiB/s, done.
# Resolving deltas: 100% (1332/1332), done.
# /content/TP_MCTS

# %%
# Install dependencies
# !pip -q install dill numpy

# %%
# Small/easier domain for quick runs with higher success.
# Simple-10 with a larger deadline.
# !python -u unified_planning/run_domain.py --domain simple --garbage_amount 10 --deadline 25 --runs 20 --search_time 1 --selection_type rootInterval 2>&1 | \
  tee run.log | awk '/^Started round/ {count++; print "Progress:", count "/20"}' ; \
  grep -E "Completed|Amount of success|Average success time|STD success time" run.log
# Out:
# Progress: 1/20
# Progress: 2/20
# Progress: 3/20
# Progress: 4/20
# Progress: 5/20
# Progress: 6/20
# Progress: 7/20
# Progress: 8/20
# Progress: 9/20
# Progress: 10/20
# Progress: 11/20
# Progress: 12/20
# Progress: 13/20
# Progress: 14/20
# Progress: 15/20
# Progress: 16/20
# Progress: 17/20
# Progress: 18/20
# Progress: 19/20
# Progress: 20/20
# Completed = 20
# Amount of success = 0
# Average success time = -inf
# STD success time = -1

# %%
# After run finishes, show summary lines
# !grep -E "Completed|Amount of success|Average success time|STD success time" run.log

# %%
import sys, platform, os
print("executable:", sys.executable)
print("platform:", platform.platform())
print("cwd:", os.getcwd())
print("has /content:", os.path.exists("/content"))
# Out:
# executable: /usr/bin/python3
# platform: Linux-6.6.105+-x86_64-with-glibc2.35
# cwd: /content/TP_MCTS
# has /content: True

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      2
#   On-line CPU(s) list:       0,1
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   79
#     Thread(s) per core:      2
#     Core(s) per socket:      1
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4399.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
# ...
